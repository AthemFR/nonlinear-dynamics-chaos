# %% [markdown]
# # Hysteresis in the Lorenz attractor:
#
# Solve the Lorenz equations numerically using Python.
#
# $$
# \begin{aligned}
# \dot{x} &= \sigma (y - x), \\
# \dot{y} &= r x - y - x z, \\
# \dot{z} &= x y - b z.
# \end{aligned}
# $$

# %%
# Importing libraries:
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import pyvista as pv

# %% [markdown]
# ### Define ODE:

# %%
# ODE system
def system(t, state):
    """
    Input State -> [x, y, z]
    Outputs -> [dxdt, dydt, dzdt]
    """
    x, y, z = state
    
    # Slopes
    dxdt = s*(y - x)
    dydt = r*x - y - x*z
    dzdt = x*y - b*z
    
    return [dxdt, dydt, dzdt]

# %% [markdown]
# ### Run parameters

# %%
# Fixed parameters: Lorenz simulation
s = 10.
b = 8./3.
r = 350 # limit cycle for all r> 313

# %% [markdown]
# ### Critical value for Hopf bifurcation:

# %%
# Calculate critical r for Hoptf bifurcation
r_h = s*(s + b + 3.)/(s - b - 1.)

print(r_h)
# Out:
# 24.736842105263154

# %% [markdown]
# ### Time domain and ICs

# %%
# Time limits
t_lims = [0., 30.]

# Time axis
t_axis = np.linspace(t_lims[0], t_lims[1], 10000)

# %%
# Initial conditions
#ics = [[0., 1., 0.], [0., 1.01, 0.]] # Expand to see other trajectories
ics = [[5., 5., 5.]] # Expand to see other trajectories

# %% [markdown]
# ### 3D representation of the trajectory/ies

# %%
# Figure environment

plt.figure(figsize = (10,8))

# Integrate and plot trajectories
for x0, y0, z0 in ics:
    
    # Integrate and plot trajectories
    sol = solve_ivp(system, t_lims, [x0, y0, z0], t_eval=t_axis, method='RK45')
    #print(sol)
    plt.plot(sol.y[0],sol.y[2])

plt.show()

# %% [markdown]
# ### Evolution of the Y coordinate:

# %%
# Figure environment.
plt.figure(figsize=(11, 3))

plt.plot(sol.t, sol.y[0])

plt.xlabel(r"$t$")
plt.ylabel(r"$y(t)$")

plt.show()

# %%
points = np.stack((sol.y[0], sol.y[1], sol.y[2]), axis=1)

cloud = pv.PolyData(points)

cloud['time'] = sol.t

output_file = 'large-Rayleigh.vtp'

cloud.save(output_file)
