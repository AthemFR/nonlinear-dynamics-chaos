# %% [markdown]
# # Lorenz map:
#
# Solve the Lorenz equations numerically using Python.
#
# $$
# \begin{aligned}
# \dot{x} &= \sigma (y - x), \\
# \dot{y} &= r x - y - x z, \\
# \dot{z} &= x y - b z.
# \end{aligned}
# $$

# %%
# Importing libraries:
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import pyvista as pv

# %% [markdown]
# ### Define ODE:

# %%
# ODE system
def system(t, state):
    """
    Input State -> [x, y, z]
    Outputs -> [dxdt, dydt, dzdt]
    """
    x, y, z = state
    
    # Slopes
    dxdt = s*(y - x)
    dydt = r*x - y - x*z
    dzdt = x*y - b*z
    
    return [dxdt, dydt, dzdt]

# %% [markdown]
# ### Run parameters

# %%
# Fixed parameters: Lorenz simulation
s = 10.
b = 8./3.
r = 28.

# %% [markdown]
# ### Critical value for Hopf bifurcation:

# %%
# Calculate critical r for Hoptf bifurcation
r_h = s*(s + b + 3.)/(s - b - 1.)

print(r_h)
# Out:
# 24.736842105263154

# %% [markdown]
# ### Time domain and ICs

# %%
# Time limits
t_lims = [0., 200.]

# Time axis
t_axis = np.linspace(t_lims[0], t_lims[1], 100000)

# %%
# Initial conditions
ics = [[0., 1., 0.]] # Expand to see other trajectories
#ics = [[5., 5., 5.]] # Expand to see other trajectories

# %% [markdown]
# ### 3D representation of the trajectory/ies

# %%
# Figure environment

fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(projection ='3d')

# Integrate and plot trajectories
for x0, y0, z0 in ics:
    
    # Integrate and plot trajectories
    sol = solve_ivp(system, t_lims, [x0, y0, z0], t_eval=t_axis, method='RK45')
    #print(sol)
    ax.plot(sol.y[0], sol.y[1], sol.y[2])

    #ax.view_init(elev=30, azim=10, roll=50)

    #ax.plot(sol.t, sol.y[1])

plt.show()

# %% [markdown]
# ### Evolution of the Z coordinate:

# %%
# Figure environment.
plt.figure(figsize=(11, 3))

plt.plot(sol.t, sol.y[2])

plt.xlabel(r"$t$")
plt.ylabel(r"$z(t)$")

plt.show()

# %% [markdown]
# # Lorenz Map:

# %%
import scipy.signal as ss

# %%
maxima = ss.argrelextrema(sol.y[2], np.greater_equal, mode = 'clip')
#print(maxima)
t_max = sol.t[maxima]
z_max = sol.y[2][maxima]

#idx = np.where(y_max > 0)

#t_max = sol.t[idx]
#y_max = sol.y[0][idx]

# %%
# Figure environment.
plt.figure(figsize=(11, 3))

plt.plot(sol.t, sol.y[2])
plt.plot(t_max, z_max, marker = "o", linestyle = " ")

plt.xlabel(r"$t$")
plt.ylabel(r"$y(t)$")

plt.show()

# %%
#print(z_max[:])
#print(z_max[1:])
#print(z_max[:-1])

# %%
# Figure environment.
plt.figure(figsize=(4, 4))

#plt.plot(sol.t, sol.y[0])
plt.plot(z_max[:-1], z_max[1:], marker = "o", linestyle = " ")

plt.plot(z_max, z_max, "-")

plt.xlabel(r"$z_n$")
plt.ylabel(r"$z_{n+1}$")

#plt.xlim(10, 20)
#plt.ylim(10, 20)

plt.show()
